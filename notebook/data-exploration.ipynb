# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path().resolve().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
from src.config import RAW_DATA_DIR

# %%
# import dataset
df = pd.read_csv(RAW_DATA_DIR / 'youtube_raw_20260621_031735.csv')

# %%
df[df['source'] == 'search']
# Out:
#          video_id                                              title  \
# 400   HRfb4NVD8LE  Blaqbonez - Chanel (feat. Asake) [Official Mus...
# 401   MS7I2kVp0bw  Johnny Drille, Ayra Starr & Young Jonn - Color...
# 402   txrYKA8Zg4g  CG5 - Not Supposed To Love Me [Ode to JAX] (Th...
# 403   _yikWXUvyEw  JANUARY 2026 NAIJA MUSIC/MIX | AFRO-OVERLOAD 5...
# 404   YdrW1SJwiMs           Tyla - IS IT LOVE (Official Music Video)
# ...           ...                                                ...
# 5812  Xtgt9HONWzw                         Ranking Food Game (part.3)
# 5813  9tHmOxXAVRI             48 Hours Eating Vancouver's BEST Food!
# 5814  5DSf3_H54m8  I Tried Dwarka Most Overhyped Food Places By V...
# 5815  KRQj5yEviuU  Street Style Noodles Burger in Just 35/-😋🥵 #fo...
# 5816  79eY_hBCVu8  Summer Special NO cook Recipes #food #recipe #...
#
#                                             description  \
# 400   Blaqbonez teams up with Asake on “Chanel”  one...
# 401   Stream 'Colorado' here - JohnnyDrille.lnk.to/C...
# 402   STREAM "Not Supposed To Love Me" NOW ▶ https:/...
# 403   Instagram: https://www.instagram.com/djfreshom...
# 404   Tyla - IS IT LOVE (Official Music Video)\n\n"I...
# ...                                                 ...
# 5812  Ranking Food Game (part.3)\n\nThe KVFN edit st...
# 5813  Vancouver is the best place to eat Asian food ...
# 5814  Hello everyone in this visit I visited Dwarka ...
# 5815                                                NaN
# 5816                                                NaN
#
#                     channel_id       channel_title          published_at  \
# 400   UC0iZ_gqCk22K0jWscf75lhg           Blaqbonez  2026-05-21T20:00:06Z
# 401   UCr2CrvCc_tu8dkcmik0SLeA       Johnny Drille  2026-04-17T17:00:14Z
# 402   UCLCdyRg3u5O-EVP5p46QxcQ                 CG5  2026-06-20T22:00:06Z
# 403   UCHvH9MJlpU3xlSKFHZEM6Sg       DJ Fresh Oman  2025-12-25T17:32:59Z
# 404   UCr2xjaS7CIx1OY7hYwrXb8A            TylaVEVO  2026-06-18T16:00:06Z
# ...                        ...                 ...                   ...
# 5812  UCjZHe5hFSTs9hmGGJR3_yxA                KVFN  2026-06-05T04:00:00Z
# 5813  UCHlyAg6cE1n8nHdAAmar0zg         Only Scrans  2026-06-14T09:00:04Z
# 5814  UCyubW6s9H4cdxtrfbhoG1Sg     Help With Harsh  2026-05-16T07:27:59Z
# 5815  UCy-pIJQu39gJqJDpdC1jALQ     sardaarjifoodie  2026-06-17T06:05:00Z
# 5816  UC2VycAHB7o-gaAUwstAUNXg  Kitchen with Anaya  2026-06-14T09:01:57Z
#
#       category_id                                               tags  \
# 400            10  ['Blaqbonez', 'Blaqbones', 'Blaqbonez chanel',...
# 401            10                                                 []
# 402            10  ['cg5', 'cg5 song', 'the amazing digital circu...
# 403            24                                                 []
# 404            10  ['tyla', 'new artist', 'getting late', 'tyla t...
# ...           ...                                                ...
# 5812           24                              ['food game', 'food']
# 5813           24                                                 []
# 5814           22  ['Dwarka', 'Dwarka Delhi', 'Dwarka overhyped f...
# 5815           22                                                 []
# 5816           22  ['kitchen with anaya', 'cooking vlogs', 'kitch...
#
#          views   likes  comments  engagement_rate    duration  source  \
# 400    3700094   54817      2208         0.015412     PT2M51S  search
# 401    4852775   44634      1678         0.009543     PT4M16S  search
# 402     194933   34871      3582         0.197263      PT4M1S  search
# 403    1290723    9795       279         0.007805  PT1H14M44S  search
# 404    1172950   72189      5929         0.066600     PT3M11S  search
# ...        ...     ...       ...              ...         ...     ...
# 5812  16284114  292556       238         0.017980       PT52S  search
# 5813    181725    5252       464         0.031454    PT23M59S  search
# 5814   1283654   39083        66         0.030498       PT43S  search
# 5815    131659    2952        10         0.022498       PT26S  search
# 5816    142139    4451        44         0.031624     PT2M48S  search
#
#                     collected_at
# 400   2026-06-21T02:17:34.948080
# 401   2026-06-21T02:17:34.948099
# 402   2026-06-21T02:17:34.948106
# 403   2026-06-21T02:17:34.948113
# 404   2026-06-21T02:17:34.948120
# ...                          ...
# 5812  2026-06-21T02:17:34.990825
# 5813  2026-06-21T02:17:34.990830
# 5814  2026-06-21T02:17:34.990836
# 5815  2026-06-21T02:17:34.990841
# 5816  2026-06-21T02:17:34.990847
#
# [5417 rows x 15 columns]
