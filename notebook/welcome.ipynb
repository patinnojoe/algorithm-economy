# %%
import sys
import os

print(f"👋 Kernel Python Path: {sys.executable}")
print(f"📁 Current Workspace:  {os.getcwd()}")
print("hello world")
# Out:
# 👋 Kernel Python Path: /Users/pro2020/projects/python/social-media-algorithm-analysis/social_media_analyis_venv/bin/python
# 📁 Current Workspace:  /Users/pro2020/projects/python/social-media-algorithm-analysis/notebook
# hello world
